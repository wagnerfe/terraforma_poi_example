# %% [markdown]
# <a href="https://colab.research.google.com/github/wagnerfe/terraforma_poi_example/blob/main/poi_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import geopandas as gpd
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# As we will later visualize some data on a map, we need to install an additional package. In colab this can be done within the notebook using pip.

# %%
# !pip install mapclassify

# %% [markdown]
# ## Load data
# Some sample POI data from Overture is stored in a public drive folder here: https://drive.google.com/file/d/1cRFgZpyt5_4hriSnqan2i5VYV6c5Ee9O/view?usp=sharing
#
# We first have to download the data to our local drive.

# %%
# !gdown --folder --remaining-ok https://drive.google.com/drive/folders/10UPqAbnqX5YzLFC45KVEt-OkCdi85MKO?usp=drive_link -O /content/data/
# Out:
# Retrieving folder contents
# Processing file 1cRFgZpyt5_4hriSnqan2i5VYV6c5Ee9O santa_cruz_pois.geojson
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1cRFgZpyt5_4hriSnqan2i5VYV6c5Ee9O
# To: /content/data/shared/santa_cruz_pois.geojson
# 100% 1.15M/1.15M [00:00<00:00, 15.4MB/s]
# Download completed

# %% [markdown]
# ## Inspect data
# Now that we have it in our local directory (see directory structure on the left), we can load and inspect the file using geopandas.

# %%
gdf = gpd.read_file('/content/data/shared/santa_cruz_pois.geojson')

# %%
gdf.head()
# Out:
#                                                names  \
# 0  { "primary": "Fern Grotto Beach", "common": nu...
# 1  { "primary": "Kobay Lila Caylee York", "common...
# 2  { "primary": "Dha Brain Kid - ช่วยพัฒนาสมองเด็...
# 3  { "primary": "Kota Yareli Jewel Gunn", "common...
# 4  { "primary": "Spyglass Hill golf course", "com...
#
#                       geometry
# 0  POINT (-122.08716 36.95441)
# 1  POINT (-122.08543 36.96033)
# 2  POINT (-122.08543 36.96033)
# 3  POINT (-122.08543 36.96033)
# 4   POINT (-122.0871 36.97588)

# %% [markdown]
# ## Visualize the data

# %%
gdf.sample(n=500, random_state=0).explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
